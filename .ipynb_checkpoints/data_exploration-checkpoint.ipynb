# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/us-cities-demographics.csv", sep=';')

# %%
df.head()
# Out:
#           City          State  Median Age  Male Population  Female Population  \
# 0   Framingham  Massachusetts        40.3          35442.0            35768.0
# 1         Waco          Texas        29.3          63452.0            68890.0
# 2   Fort Worth          Texas        32.6         414126.0           422843.0
# 3   Bellingham     Washington        30.7          41286.0            43857.0
# 4  Maple Grove      Minnesota        38.6          31780.0            36601.0
#
#    Total Population  Number of Veterans  Foreign-born  Average Household Size  \
# 0             71210              2625.0       19070.0                    2.49
# 1            132342             10716.0       14235.0                    2.57
# 2            836969             39182.0      143404.0                    2.88
# 3             85143              4703.0        8713.0                    2.44
# 4             68381              2943.0        7645.0                    2.64
#
# ...

# %%
len(df)
# Out:
# 2891

# %%
df_temperature = pd.read_csv('dataset/29_2150_bundle_archive/GlobalLandTemperaturesByCity.csv')

# %%
df_temperature.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
len(df_temperature)
# Out:
# 8599212

# %%
df_temperature[df_temperature["dt"] > '2000-01-01']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3075     2000-02-01               3.724                          0.241
# 3076     2000-03-01               3.976                          0.296
# 3077     2000-04-01               8.321                          0.221
# 3078     2000-05-01              13.567                          0.253
# 3079     2000-06-01              14.702                          0.240
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 3075      Århus      Denmark   57.05N    10.33E
# ...

# %%
df_temperature["Country"].unique()
# Out:
# array(['Denmark', 'Turkey', 'Kazakhstan', 'China', 'Spain', 'Germany',
#        'Nigeria', 'Iran', 'Russia', 'Canada', "Côte D'Ivoire",
#        'United Kingdom', 'Saudi Arabia', 'Japan', 'United States',
#        'India', 'Benin', 'United Arab Emirates', 'Mexico', 'Venezuela',
#        'Ghana', 'Ethiopia', 'Australia', 'Yemen', 'Indonesia', 'Morocco',
#        'Pakistan', 'France', 'Libya', 'Burma', 'Brazil', 'South Africa',
#        'Syria', 'Egypt', 'Algeria', 'Netherlands', 'Malaysia', 'Portugal',
#        'Ecuador', 'Italy', 'Uzbekistan', 'Philippines', 'Madagascar',
#        'Chile', 'Belgium', 'El Salvador', 'Romania', 'Peru', 'Colombia',
#        'Tanzania', 'Tunisia', 'Turkmenistan', 'Israel', 'Eritrea',
#        'Paraguay', 'Greece', 'New Zealand', 'Vietnam', 'Cameroon', 'Iraq',
#        'Afghanistan', 'Argentina', 'Azerbaijan', 'Moldova', 'Mali',
#        'Congo (Democratic Republic Of The)', 'Thailand',
# ...

# %%
df_temperature['Country'] == 'United States'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 8599207    False
# 8599208    False
# 8599209    False
# 8599210    False
# 8599211    False
# Name: Country, Length: 8599212, dtype: bool

# %%
df_usa = df_temperature[(df_temperature["dt"] > '2000-01-01') & (df_temperature['Country'] == 'United States')]

# %%
df_usa['City'].unique()
# Out:
# array(['Abilene', 'Akron', 'Albuquerque', 'Alexandria', 'Allentown',
#        'Amarillo', 'Anaheim', 'Anchorage', 'Ann Arbor', 'Antioch',
#        'Arlington', 'Arvada', 'Atlanta', 'Aurora', 'Austin',
#        'Bakersfield', 'Baltimore', 'Baton Rouge', 'Beaumont', 'Bellevue',
#        'Berkeley', 'Birmingham', 'Boston', 'Bridgeport', 'Brownsville',
#        'Buffalo', 'Burbank', 'Cambridge', 'Cape Coral', 'Carrollton',
#        'Cary', 'Cedar Rapids', 'Chandler', 'Charleston', 'Charlotte',
#        'Chattanooga', 'Chesapeake', 'Chicago', 'Chula Vista',
#        'Cincinnati', 'Clarksville', 'Clearwater', 'Cleveland',
#        'Colorado Springs', 'Columbia', 'Columbus', 'Concord',
#        'Coral Springs', 'Corona', 'Corpus Christi', 'Costa Mesa',
#        'Dallas', 'Dayton', 'Denton', 'Denver', 'Des Moines', 'Detroit',
#        'Downey', 'Durham', 'East Los Angeles', 'Edison', 'El Monte',
#        'El Paso', 'Elizabeth', 'Escondido', 'Eugene', 'Evansville',
# ...

# %%
df_usa[df_usa['City'] == 'Cambridge']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 1326736  2000-02-01              -2.449                          0.267
# 1326737  2000-03-01               4.065                          0.163
# 1326738  2000-04-01               6.868                          0.206
# 1326739  2000-05-01              13.585                          0.319
# 1326740  2000-06-01              18.428                          0.298
# ...             ...                 ...                            ...
# 1326895  2013-05-01              14.309                          0.331
# 1326896  2013-06-01              19.313                          0.353
# 1326897  2013-07-01              23.629                          0.447
# 1326898  2013-08-01              19.579                          0.336
# 1326899  2013-09-01              15.883                          1.368
#
#               City        Country Latitude Longitude
# 1326736  Cambridge  United States   42.59N    72.00W
# ...

# %%
df_usa[df_usa['dt'] == '2012-10-01']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 49868    2012-10-01              16.702                          0.264
# 140293   2012-10-01              11.558                          0.193
# 170388   2012-10-01              12.781                          0.381
# 190755   2012-10-01              13.607                          0.329
# 205478   2012-10-01              12.436                          0.344
# ...             ...                 ...                            ...
# 8215671  2012-10-01              16.698                          0.248
# 8224030  2012-10-01              10.758                          0.296
# 8230210  2012-10-01              15.014                          0.203
# 8255479  2012-10-01              10.966                          0.335
# 8439235  2012-10-01              12.436                          0.344
#
#                   City        Country Latitude Longitude
# 49868          Abilene  United States   32.95N   100.53W
# ...

# %%
df = pd.read_csv("dataset/us-cities-demographics.csv", sep=';')

# %%
df.head()
# Out:
#           City          State  Median Age  Male Population  Female Population  \
# 0   Framingham  Massachusetts        40.3          35442.0            35768.0
# 1         Waco          Texas        29.3          63452.0            68890.0
# 2   Fort Worth          Texas        32.6         414126.0           422843.0
# 3   Bellingham     Washington        30.7          41286.0            43857.0
# 4  Maple Grove      Minnesota        38.6          31780.0            36601.0
#
#    Total Population  Number of Veterans  Foreign-born  Average Household Size  \
# 0             71210              2625.0       19070.0                    2.49
# 1            132342             10716.0       14235.0                    2.57
# 2            836969             39182.0      143404.0                    2.88
# 3             85143              4703.0        8713.0                    2.44
# 4             68381              2943.0        7645.0                    2.64
#
# ...

# %%
len(df)
# Out:
# 2891

# %%
df_temperature = pd.read_csv('dataset/29_2150_bundle_archive/GlobalLandTemperaturesByCity.csv')

# %%
df_temperature.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
len(df_temperature)
# Out:
# 8599212

# %%
df_temperature[df_temperature["dt"] > '2000-01-01']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 3075     2000-02-01               3.724                          0.241
# 3076     2000-03-01               3.976                          0.296
# 3077     2000-04-01               8.321                          0.221
# 3078     2000-05-01              13.567                          0.253
# 3079     2000-06-01              14.702                          0.240
# ...             ...                 ...                            ...
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 3075      Århus      Denmark   57.05N    10.33E
# ...

# %%
df_temperature["Country"].unique()
# Out:
# array(['Denmark', 'Turkey', 'Kazakhstan', 'China', 'Spain', 'Germany',
#        'Nigeria', 'Iran', 'Russia', 'Canada', "Côte D'Ivoire",
#        'United Kingdom', 'Saudi Arabia', 'Japan', 'United States',
#        'India', 'Benin', 'United Arab Emirates', 'Mexico', 'Venezuela',
#        'Ghana', 'Ethiopia', 'Australia', 'Yemen', 'Indonesia', 'Morocco',
#        'Pakistan', 'France', 'Libya', 'Burma', 'Brazil', 'South Africa',
#        'Syria', 'Egypt', 'Algeria', 'Netherlands', 'Malaysia', 'Portugal',
#        'Ecuador', 'Italy', 'Uzbekistan', 'Philippines', 'Madagascar',
#        'Chile', 'Belgium', 'El Salvador', 'Romania', 'Peru', 'Colombia',
#        'Tanzania', 'Tunisia', 'Turkmenistan', 'Israel', 'Eritrea',
#        'Paraguay', 'Greece', 'New Zealand', 'Vietnam', 'Cameroon', 'Iraq',
#        'Afghanistan', 'Argentina', 'Azerbaijan', 'Moldova', 'Mali',
#        'Congo (Democratic Republic Of The)', 'Thailand',
# ...

# %%
df_temperature['Country'] == 'United States'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 8599207    False
# 8599208    False
# 8599209    False
# 8599210    False
# 8599211    False
# Name: Country, Length: 8599212, dtype: bool

# %%
df_usa = df_temperature[(df_temperature["dt"] > '2000-01-01') & (df_temperature['Country'] == 'United States')]

# %%
df_usa['City'].unique()
# Out:
# array(['Abilene', 'Akron', 'Albuquerque', 'Alexandria', 'Allentown',
#        'Amarillo', 'Anaheim', 'Anchorage', 'Ann Arbor', 'Antioch',
#        'Arlington', 'Arvada', 'Atlanta', 'Aurora', 'Austin',
#        'Bakersfield', 'Baltimore', 'Baton Rouge', 'Beaumont', 'Bellevue',
#        'Berkeley', 'Birmingham', 'Boston', 'Bridgeport', 'Brownsville',
#        'Buffalo', 'Burbank', 'Cambridge', 'Cape Coral', 'Carrollton',
#        'Cary', 'Cedar Rapids', 'Chandler', 'Charleston', 'Charlotte',
#        'Chattanooga', 'Chesapeake', 'Chicago', 'Chula Vista',
#        'Cincinnati', 'Clarksville', 'Clearwater', 'Cleveland',
#        'Colorado Springs', 'Columbia', 'Columbus', 'Concord',
#        'Coral Springs', 'Corona', 'Corpus Christi', 'Costa Mesa',
#        'Dallas', 'Dayton', 'Denton', 'Denver', 'Des Moines', 'Detroit',
#        'Downey', 'Durham', 'East Los Angeles', 'Edison', 'El Monte',
#        'El Paso', 'Elizabeth', 'Escondido', 'Eugene', 'Evansville',
# ...

# %%
df_usa[df_usa['City'] == 'Cambridge']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 1326736  2000-02-01              -2.449                          0.267
# 1326737  2000-03-01               4.065                          0.163
# 1326738  2000-04-01               6.868                          0.206
# 1326739  2000-05-01              13.585                          0.319
# 1326740  2000-06-01              18.428                          0.298
# ...             ...                 ...                            ...
# 1326895  2013-05-01              14.309                          0.331
# 1326896  2013-06-01              19.313                          0.353
# 1326897  2013-07-01              23.629                          0.447
# 1326898  2013-08-01              19.579                          0.336
# 1326899  2013-09-01              15.883                          1.368
#
#               City        Country Latitude Longitude
# 1326736  Cambridge  United States   42.59N    72.00W
# ...

# %%
df_usa[df_usa['dt'] == '2012-11-01']
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 49869    2012-11-01              13.892                          0.286
# 140294   2012-11-01               4.185                          0.227
# 170389   2012-11-01               6.284                          0.565
# 190756   2012-11-01               5.487                          0.347
# 205479   2012-11-01               4.103                          0.298
# ...             ...                 ...                            ...
# 8215672  2012-11-01              13.219                          0.308
# 8224031  2012-11-01               3.800                          0.222
# 8230211  2012-11-01               7.672                          0.345
# 8255480  2012-11-01               2.938                          0.235
# 8439236  2012-11-01               4.103                          0.298
#
#                   City        Country Latitude Longitude
# 49869          Abilene  United States   32.95N   100.53W
# ...

# %%
#!pip3.8 install geopy

# %%
import geopy

# %%
from geopy.geocoders import Nominatim

# %%
geolocator = Nominatim(user_agent="my_app")

# %%
location = geolocator.reverse("42.59N, 72.00W")

# %%
print(location.address)
# Out:
# 444, Park Street, Olde English Village, Gardner, Worcester County, Massachusetts, 01440, United States of America

# %%
location.raw
# Out:
# {'place_id': 137514281,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 213308175,
#  'lat': '42.590085849999994',
#  'lon': '-71.99971655690173',
#  'display_name': '444, Park Street, Olde English Village, Gardner, Worcester County, Massachusetts, 01440, United States of America',
#  'address': {'house_number': '444',
#   'road': 'Park Street',
#   'hamlet': 'Olde English Village',
#   'city': 'Gardner',
#   'county': 'Worcester County',
#   'state': 'Massachusetts',
#   'postcode': '01440',
#   'country': 'United States of America',
#   'country_code': 'us'},
#  'boundingbox': ['42.5900336', '42.5901838', '-71.9997768', '-71.9996546']}

# %%
location.raw['address']['state']
# Out:
# 'Massachusetts'

# %%
print(location.address)
# Out:
# Steinecke, Potsdamer Platz, Tiergarten, Mitte, Berlin, 10785, Deutschland
